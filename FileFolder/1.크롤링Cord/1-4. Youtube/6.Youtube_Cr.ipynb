# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime, timedelta
import openpyxl  # openpyxl 모듈 추가
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import json

sns.set_style('darkgrid')
sns.set_palette('Set3')
warnings.filterwarnings('ignore')
plt.rcParams["font.family"] = "NanumBarunGothic"

# %%
# 시작일과 종료일 설정
start_day = datetime(2024, 4, 22)
end_day = datetime(2024, 4, 29)
Count_end_day = end_day.strftime("%Y%m%d")

# 시작일과 종료일 사이의 주count 계산
total_weeks = ((end_day - start_day).days // 7)

# 엑셀 파일 생성
wb = openpyxl.Workbook() 
ws = wb.active
ws.append(["Day", "Rank", "Title_Name", "Cover_Img", "Singer","View", "video_url"])

# 주 단위로 날짜 출력
current_day = start_day
print(f"시작일 : {start_day}, 종료일 : {end_day}")
Week_Count = 0

while current_day <= end_day:
    week_start = current_day.strftime("%Y%m%d")
    week_end = (current_day + timedelta(days=6)).strftime("%Y%m%d")
    # print(f"{week_start}~{week_end}")
    current_day += timedelta(weeks=1)
    
    date =  (current_day + timedelta(days=-4)).strftime("%Y%m%d")
    # URL 뒤에 들어갈 날짜
   
   
    # Chrome 브라우저를 띄우지 않고 실행하는 옵션 설정
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # 브라우저를 화면에 표시하지 않음

    # Chrome 드라이버 생성
    driver = webdriver.Chrome(options=chrome_options)

    url = "https://charts.youtube.com/charts/TopSongs/kr/weekly/{0}".format(date)
    driver.get(url)
    print(url)
    print(f"Count : {date} / End_Count : {Count_end_day}")

    # 페이지가 로드될 때까지 잠시 대기
    time.sleep(5)

    # 페이지 소스 가져오기
    html = driver.page_source

    # BeautifulSoup을 사용하여 HTML 파싱
    soup = BeautifulSoup(html, 'html.parser')

    # 데이터를 담을 리스트 생성
    data_list = []

    # 각 아이템에 대한 정보를 가져와서 리스트에 추가
    for item in soup.select('.data-table-container.style-scope.ytmc-entry-row'):
        Ranking = item.select_one('.rank-container.center.style-scope.ytmc-entry-row #rank').text.strip()
        Cover_img = item.select_one('.thumbnail-container.center.style-scope.ytmc-entry-row img').get('src')
        Title = item.select_one('.title.style-scope.ytmc-entry-row').text.strip() if item.select_one('.title.style-scope.ytmc-entry-row') else ""
        Artist_name = item.select_one('.subtitle.style-scope.ytmc-entry-row span.style-scope.ytmc-entry-row').text.strip()
        # views를 가져오는 부분 수정
        views_elements = item.select('.metric.content.center.tablet-non-displayed-metric.style-scope.ytmc-entry-row')
        Views = views_elements[1].text.strip() if len(views_elements) >= 2 else ""
        # 이미지 태그를 가져옴
        Video_url = item.select_one('.thumbnail-container.center.style-scope.ytmc-entry-row img').get('endpoint')
        
        for line in Video_url.split('\n'):
            if line.strip():
                # JSON 형식의 문자열을 파이썬 객체로 변환
                data = json.loads(line)
                # URL을 출력
                Video_URL = data['urlEndpoint']['url']
                print(Video_URL)
                
        data_list.append({
            "날짜 ": (current_day + timedelta(days=-5)).strftime("%Y%m%d"),
            "랭킹 ": Ranking,
            "제목 ": Title,
            "Cover_Img": Cover_img,
            "가수 ": Artist_name,
            "조회수 ": Views,
            "영상URL" : Video_URL
        })
        for ranking, title, cover_img, artist_name, view, video_URL in zip(Ranking, Title, Cover_img, Artist_name, Views, Video_URL):
            ws.append([(current_day + timedelta(days=-5)).strftime("%Y%m%d"), Ranking, Title, Cover_img, Artist_name, Views, Video_URL])
      
    # 결과 출력
    for data in data_list:
        #print(data)
        data

    # 브라우저 종료
    driver.quit()



# 엑셀 파일 저장
file_path = r"C:\P_Project\1.Project\5-Project_data\6.Youtube_Crawling_Final4.29.xlsx"
wb.save(file_path)
print("Excel 파일이 저장되었습니다:", file_path)
# Out:
# 시작일 : 2024-04-22 00:00:00, 종료일 : 2024-04-29 00:00:00
# https://charts.youtube.com/charts/TopSongs/kr/weekly/20240425
# Count : 20240425 / End_Count : 20240429
# https://www.youtube.com/watch?v=Vk5-c_v4gMU
# https://www.youtube.com/watch?v=ImuWa3SJulY
# https://www.youtube.com/watch?v=ATK7gAaZTOM
# https://www.youtube.com/watch?v=hVAc1Vf2ITU
# https://www.youtube.com/watch?v=2wA_b6YHjqQ
# https://www.youtube.com/watch?v=Ey53EQhkLY8
# https://www.youtube.com/watch?v=smdmEhkIRVc
# https://www.youtube.com/watch?v=JleoAppaxi0
# https://www.youtube.com/watch?v=vnS_jn2uibs
# https://www.youtube.com/watch?v=KNexS61fjus
# https://www.youtube.com/watch?v=fQ84rvbfa08
# https://www.youtube.com/watch?v=D8VEhcPeSlc
# https://www.youtube.com/watch?v=5_n6t9G2TUQ
# https://www.youtube.com/watch?v=9JFi7MmjtGA
# https://www.youtube.com/watch?v=bNKXxwOQYB8
# https://www.youtube.com/watch?v=oKVYm8mIUdo
# https://www.youtube.com/watch?v=WGm2HmXeeRI
# https://www.youtube.com/watch?v=Oa_RSwwpPaA
# https://www.youtube.com/watch?v=QU9c0053UAU
# https://www.youtube.com/watch?v=hLvWy2b857I
# https://www.youtube.com/watch?v=TyCYGCCD6iQ
# https://www.youtube.com/watch?v=q3zqJs7JUCQ
# https://www.youtube.com/watch?v=js1CtxSY38I
# https://www.youtube.com/watch?v=Z4qVfCi_lUI
# https://www.youtube.com/watch?v=POe9SOEKotk
# https://www.youtube.com/watch?v=3kGAlp_PNUg
# https://www.youtube.com/watch?v=RowlrvmyFEk
# https://www.youtube.com/watch?v=tJut2wIsC1w
# https://www.youtube.com/watch?v=IMWT6937uUs
# https://www.youtube.com/watch?v=gH1rVdXUlpo
# https://www.youtube.com/watch?v=hkROGL9id6Y
# https://www.youtube.com/watch?v=eQNHDV7lKgE
# https://www.youtube.com/watch?v=mLW35YMzELE
# https://www.youtube.com/watch?v=ArmDp-zijuc
# https://www.youtube.com/watch?v=u9nP3qXQA4o
# https://www.youtube.com/watch?v=H0lQwJPdoBU
# https://www.youtube.com/watch?v=T5BxR0KNyyQ
# https://www.youtube.com/watch?v=jOTfBlKSQYY
# https://www.youtube.com/watch?v=UCmgGZbfjmk
# https://www.youtube.com/watch?v=fx227oTnnPc
# https://www.youtube.com/watch?v=1Swg-aBO9eY
# https://www.youtube.com/watch?v=59DAuFD9D0U
# https://www.youtube.com/watch?v=7UecFm_bSTU
# https://www.youtube.com/watch?v=Os_heh8vPfs
# https://www.youtube.com/watch?v=SX_ViT4Ra7k
# https://www.youtube.com/watch?v=mFbILexYSQg
# https://www.youtube.com/watch?v=C2YKyrhuygI
# https://www.youtube.com/watch?v=gQlMMD8auMs
# https://www.youtube.com/watch?v=7Fsie5WvzFM
# https://www.youtube.com/watch?v=oZpYEEcvu5I
# https://www.youtube.com/watch?v=F8c8f2nK82w
# https://www.youtube.com/watch?v=m6M6awqPPns
# https://www.youtube.com/watch?v=AhmRaCQayv8
# https://www.youtube.com/watch?v=Jmr_EEDkV-U
# https://www.youtube.com/watch?v=2-P-NIiLiQc
# https://www.youtube.com/watch?v=Qg5Gov_dTSY
# https://www.youtube.com/watch?v=GjyMuHmzxVE
# https://www.youtube.com/watch?v=l2ToQHlD2Vs
# https://www.youtube.com/watch?v=2_ZQpWVMn9c
# https://www.youtube.com/watch?v=TGz8AXN3gLA
# https://www.youtube.com/watch?v=0TAAUWHo4Ec
# https://www.youtube.com/watch?v=WxH1Vss1pLo
# https://www.youtube.com/watch?v=kHW-UVXOcLU
# https://www.youtube.com/watch?v=0JxcsbPcEpU
# https://www.youtube.com/watch?v=2S24-y0Ij3Y
# https://www.youtube.com/watch?v=jRRCWFLAO6k
# https://www.youtube.com/watch?v=rgDmqJS1S7I
# https://www.youtube.com/watch?v=6f3RzjXPQwA
# https://www.youtube.com/watch?v=mvVzdTX0yVs
# https://www.youtube.com/watch?v=_j0BOGdmh38
# https://www.youtube.com/watch?v=oMsizmQ9l5c
# https://www.youtube.com/watch?v=UZjGcAjd8Ok
# https://www.youtube.com/watch?v=sWXGbkM0tBI
# https://www.youtube.com/watch?v=Q9Nvvz6pd9g
# https://www.youtube.com/watch?v=ACiyYOz0wsQ
# https://www.youtube.com/watch?v=DiHUEWBRQEI
# https://www.youtube.com/watch?v=QkNzZUVToyM
# https://www.youtube.com/watch?v=TcHIPSX8Kww
# https://www.youtube.com/watch?v=pOR8CUeTJpc
# https://www.youtube.com/watch?v=jbjZ9kcmvD0
# https://www.youtube.com/watch?v=HFs-TxyawgA
# https://www.youtube.com/watch?v=eSW2LVbPThw
# https://www.youtube.com/watch?v=NU6XxRcx5LA
# https://www.youtube.com/watch?v=_ZfT3M6ZKEM
# https://www.youtube.com/watch?v=KpM6xNAgRoI
# https://www.youtube.com/watch?v=ucpb4BYNJ6s
# https://www.youtube.com/watch?v=baaNwRAhHBo
# https://www.youtube.com/watch?v=mNEUkkoUoIA
# https://www.youtube.com/watch?v=Amq-qlqbjYA
# https://www.youtube.com/watch?v=5_Esp-dXcOA
# https://www.youtube.com/watch?v=YApzsfazibE
# https://www.youtube.com/watch?v=8Oz7DG76ibY
# https://www.youtube.com/watch?v=IHNzOHi8sJs
# https://www.youtube.com/watch?v=jf0_fwHYAbE
# https://www.youtube.com/watch?v=8ZP5eqm4JqM
# https://www.youtube.com/watch?v=NIPtyAKxlRs
# https://www.youtube.com/watch?v=MQvGxUB-AlY
# https://www.youtube.com/watch?v=SZkkZLSCv44
# https://www.youtube.com/watch?v=ic8j13piAhQ
# https://www.youtube.com/watch?v=dMaU3Mj7EVY
# https://charts.youtube.com/charts/TopSongs/kr/weekly/20240502
# Count : 20240502 / End_Count : 20240429
# Excel 파일이 저장되었습니다: C:\P_Project\1.Project\5-Project_data\6.Youtube_Crawling_Final4.29.xlsx
