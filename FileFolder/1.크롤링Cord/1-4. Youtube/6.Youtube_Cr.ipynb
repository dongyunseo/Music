# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime, timedelta
import openpyxl  # openpyxl 모듈 추가
import re
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import json

sns.set_style('darkgrid')
sns.set_palette('Set3')
warnings.filterwarnings('ignore')
plt.rcParams["font.family"] = "NanumBarunGothic"

# %%
# 시작일과 종료일 설정
start_day = datetime(2024, 4, 22)
end_day = datetime(2024, 4, 29)
Count_end_day = end_day.strftime("%Y%m%d")

# 시작일과 종료일 사이의 주count 계산
total_weeks = ((end_day - start_day).days // 7)

# 엑셀 파일 생성
wb = openpyxl.Workbook() 
ws = wb.active
ws.append(["Day", "Rank", "Title_Name", "Cover_Img", "Singer","View", "video_url"])

# 주 단위로 날짜 출력
current_day = start_day
print(f"시작일 : {start_day}, 종료일 : {end_day}")
Week_Count = 0

while current_day <= end_day:
    week_start = current_day.strftime("%Y%m%d")
    week_end = (current_day + timedelta(days=6)).strftime("%Y%m%d")
    # print(f"{week_start}~{week_end}")
    current_day += timedelta(weeks=1)
    
    date =  (current_day + timedelta(days=-4)).strftime("%Y%m%d")
    # URL 뒤에 들어갈 날짜
   
   
    # Chrome 브라우저를 띄우지 않고 실행하는 옵션 설정
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # 브라우저를 화면에 표시하지 않음

    # Chrome 드라이버 생성
    driver = webdriver.Chrome(options=chrome_options)

    url = "https://charts.youtube.com/charts/TopSongs/kr/weekly/{0}".format(date)
    driver.get(url)
    print(url)
    print(f"Count : {date} / End_Count : {Count_end_day}")

    # 페이지가 로드될 때까지 잠시 대기
    time.sleep(5)

    # 페이지 소스 가져오기
    html = driver.page_source

    # BeautifulSoup을 사용하여 HTML 파싱
    soup = BeautifulSoup(html, 'html.parser')

    # 데이터를 담을 리스트 생성
    data_list = []

    # 각 아이템에 대한 정보를 가져와서 리스트에 추가
    for item in soup.select('.data-table-container.style-scope.ytmc-entry-row'):
        Ranking = item.select_one('.rank-container.center.style-scope.ytmc-entry-row #rank').text.strip()
        Cover_img = item.select_one('.thumbnail-container.center.style-scope.ytmc-entry-row img').get('src')
        Title = item.select_one('.title.style-scope.ytmc-entry-row').text.strip() if item.select_one('.title.style-scope.ytmc-entry-row') else ""
        Artist_name = item.select_one('.subtitle.style-scope.ytmc-entry-row span.style-scope.ytmc-entry-row').text.strip()
        # views를 가져오는 부분 수정
        views_elements = item.select('.metric.content.center.tablet-non-displayed-metric.style-scope.ytmc-entry-row')
        Views = views_elements[1].text.strip() if len(views_elements) >= 2 else ""
        # 이미지 태그를 가져옴
        Video_url = item.select_one('.thumbnail-container.center.style-scope.ytmc-entry-row img').get('endpoint')
        
        for line in Video_url.split('\n'):
            if line.strip():
                # JSON 형식의 문자열을 파이썬 객체로 변환
                data = json.loads(line)
                # URL을 출력
                Video_URL = data['urlEndpoint']['url']
        data_list.append({
            "날짜 ": (current_day + timedelta(days=-5)).strftime("%Y%m%d"),
            "랭킹 ": Ranking,
            "제목 ": Title,
            "Cover_Img": Cover_img,
            "가수 ": Artist_name,
            "조회수 ": Views,
            "영상URL" : Video_URL
        })
        for ranking, title, cover_img, artist_name, view, video_URL in zip(Ranking, Title, Cover_img, Artist_name, Views, Video_URL):
            ws.append([(current_day + timedelta(days=-5)).strftime("%Y%m%d"), Ranking, Title, Cover_img, Artist_name, Views, Video_URL])
      
    # 결과 출력
    for data in data_list:
        #print(data)
        print(data)

    # 브라우저 종료
    driver.quit()



# 엑셀 파일 저장
file_path = r"C:\P_Project\1.Project\5-Project_data\6.Youtube_Crawling_Final4.29.xlsx"
wb.save(file_path)
print("Excel 파일이 저장되었습니다:", file_path)
# Out:
# 시작일 : 2024-04-22 00:00:00, 종료일 : 2024-04-29 00:00:00
# https://charts.youtube.com/charts/TopSongs/kr/weekly/20240425
# Count : 20240425 / End_Count : 20240429
# {'날짜 ': '20240424', '랭킹 ': '1', '제목 ': 'Magnetic', 'Cover_Img': 'https://lh3.googleusercontent.com/vSYEILsfvGwSZU3PuZPU15DX0FRHcWbDnei-30-ZKQmg5XM9QKlL2BpwF9Obuvls9H3YEAMaqcusetE=w180-h180-l90-rj', '가수 ': 'ILLIT', '조회수 ': '4,977,916', '영상URL': 'https://www.youtube.com/watch?v=Vk5-c_v4gMU'}
# {'날짜 ': '20240424', '랭킹 ': '2', '제목 ': 'T.B.H', 'Cover_Img': 'https://lh3.googleusercontent.com/CSoziUkkEKh5-wM2PFXXhJJzpalvskD2Lrv9GZ9PWFbePzvEGBqX1gjntXCnbHem0F4OHEbs9LY2d2He-A=w180-h180-l90-rj', '가수 ': 'QWER', '조회수 ': '4,437,327', '영상URL': 'https://www.youtube.com/watch?v=ImuWa3SJulY'}
# {'날짜 ': '20240424', '랭킹 ': '3', '제목 ': 'Fate', 'Cover_Img': 'https://lh3.googleusercontent.com/-d5I1nv7x56NNuD3nbMZDRG874qNwua2usmDnVM35VGwHbLlLw8ozDMUrClz7f0lnSbG40L_dAF75EU8=w180-h180-l90-rj', '가수 ': '(여자)아이들', '조회수 ': '3,579,715', '영상URL': 'https://www.youtube.com/watch?v=ATK7gAaZTOM'}
# {'날짜 ': '20240424', '랭킹 ': '4', '제목 ': 'plot twist', 'Cover_Img': 'https://lh3.googleusercontent.com/JOy8WgN2RdyG0rfiMlqEXsK8IDNUHMsxtuqI5EjcIPnquJ_C4X2xdOETW3bqquYq6mqZJbLjZdQfHhPVtg=w180-h180-l90-rj', '가수 ': 'TWS', '조회수 ': '2,522,626', '영상URL': 'https://www.youtube.com/watch?v=hVAc1Vf2ITU'}
# {'날짜 ': '20240424', '랭킹 ': '5', '제목 ': 'SHEESH', 'Cover_Img': 'https://lh3.googleusercontent.com/B2D0zmOUVuYGYPkEfBv7z7kfw9xlJkk8Znzahm1ViM6fn6EYQ6hQqaCGRIP8VgvJLsq6ORXJJhRgGG-x2w=w180-h180-l90-rj', '가수 ': 'BABYMONSTER', '조회수 ': '2,391,358', '영상URL': 'https://www.youtube.com/watch?v=2wA_b6YHjqQ'}
# {'날짜 ': '20240424', '랭킹 ': '6', '제목 ': 'Impossible', 'Cover_Img': 'https://lh3.googleusercontent.com/hPJ3Qmt3oUAC72xRVbuJkLel-C9SbMBJN16FgUS220Bcmfkw3y_exqlFINRoYvqZ9SXsHgte-ddVJ3Prkw=w180-h180-l90-rj', '가수 ': 'RIIZE', '조회수 ': '2,202,457', '영상URL': 'https://www.youtube.com/watch?v=Ey53EQhkLY8'}
# {'날짜 ': '20240424', '랭킹 ': '7', '제목 ': '밤양갱', 'Cover_Img': 'https://lh3.googleusercontent.com/cizq9uWlcIXukhMyfbyhB1j9HABtLOMrsg5SSMZXa5xmgzEd2iEC0I4CLYWIrEAegbW6Vq9akiVUFRHXtw=w180-h180-l90-rj', '가수 ': '비비(BIBI)', '조회수 ': '1,882,736', '영상URL': 'https://www.youtube.com/watch?v=smdmEhkIRVc'}
# {'날짜 ': '20240424', '랭킹 ': '8', '제목 ': 'Love wins all', 'Cover_Img': 'https://lh3.googleusercontent.com/ytbkUaJaduL4gE07iKmg1LwZPMqRh-9vX7vHksmZ4VklMJLh3eU5maCsQgEv0En42cyXu0oPU6n07ZwH=w180-h180-l90-rj', '가수 ': '아이유(IU)', '조회수 ': '1,738,229', '영상URL': 'https://www.youtube.com/watch?v=JleoAppaxi0'}
# {'날짜 ': '20240424', '랭킹 ': '9', '제목 ': '한 페이지가 될 수 있게', 'Cover_Img': 'https://lh3.googleusercontent.com/MrTozy1iI0cs2MAxJ4Q-PbWxWC9Nzm3un5_X4_OOi7egWuN-x36KamzsCZ0A_S7lPXYOLjzZF-_gmOePAA=w180-h180-l90-rj', '가수 ': 'DAY6(데이식스)', '조회수 ': '1,681,489', '영상URL': 'https://www.youtube.com/watch?v=vnS_jn2uibs'}
# {'날짜 ': '20240424', '랭킹 ': '10', '제목 ': 'Smart', 'Cover_Img': 'https://lh3.googleusercontent.com/8IvBab8HMCPRrfomo1az0SlJQ1OaBtSoOK5ZtRCe524fjh5YGewjVateF-Lc67wXjAJw1zV52F6y_Dw=w180-h180-l90-rj', '가수 ': '르세라핌', '조회수 ': '1,639,193', '영상URL': 'https://www.youtube.com/watch?v=KNexS61fjus'}
# {'날짜 ': '20240424', '랭킹 ': '11', '제목 ': 'Heavenly fate', 'Cover_Img': 'https://i.ytimg.com/vi/fQ84rvbfa08/default.jpg', '가수 ': 'Lee Chang Sub', '조회수 ': '1,564,120', '영상URL': 'https://www.youtube.com/watch?v=fQ84rvbfa08'}
# {'날짜 ': '20240424', '랭킹 ': '12', '제목 ': 'Drama', 'Cover_Img': 'https://lh3.googleusercontent.com/vR3E6SvzUMgt9HwcSys34sHQQhtj62oXDbR7VYup1LM6D0unlayZOWmZnswWUZGEPUsxjpRESNHuPA0_NQ=w180-h180-l90-rj', '가수 ': 'aespa', '조회수 ': '1,473,992', '영상URL': 'https://www.youtube.com/watch?v=D8VEhcPeSlc'}
# {'날짜 ': '20240424', '랭킹 ': '13', '제목 ': 'To. X', 'Cover_Img': 'https://lh3.googleusercontent.com/lOHDJdhlasRXh3svE14DtWAZMSsiYpIMwEdLCXujcg0pPUHWvi0KpBh_459RNuODWj4s4n9lKCeHkwtP=w180-h180-l90-rj', '가수 ': '태연', '조회수 ': '1,470,994', '영상URL': 'https://www.youtube.com/watch?v=5_n6t9G2TUQ'}
# {'날짜 ': '20240424', '랭킹 ': '14', '제목 ': 'MANIAC', 'Cover_Img': 'https://lh3.googleusercontent.com/nkO-Bnt3OO4hl4wxmy66iC2EX9X7dIBAyuDzNJ7pVvdjg2r5LIVw2T7omHaAUYho1ULmu8ox1YxxkGU=w180-h180-l90-rj', '가수 ': 'VIVIZ (비비지)', '조회수 ': '1,309,461', '영상URL': 'https://www.youtube.com/watch?v=9JFi7MmjtGA'}
# {'날짜 ': '20240424', '랭킹 ': '15', '제목 ': 'EASY', 'Cover_Img': 'https://lh3.googleusercontent.com/8IvBab8HMCPRrfomo1az0SlJQ1OaBtSoOK5ZtRCe524fjh5YGewjVateF-Lc67wXjAJw1zV52F6y_Dw=w180-h180-l90-rj', '가수 ': '르세라핌', '조회수 ': '1,296,648', '영상URL': 'https://www.youtube.com/watch?v=bNKXxwOQYB8'}
# {'날짜 ': '20240424', '랭킹 ': '16', '제목 ': 'Midas Touch', 'Cover_Img': 'https://lh3.googleusercontent.com/Gr3h56VC93BfYf4hY3yHb1bmxvZLxQcLjKdyblNxGIghbke-S_mBROreE5k3sHT_VDgEWoAivAWFHbhi=w180-h180-l90-rj', '가수 ': 'KISS OF LIFE', '조회수 ': '1,283,793', '영상URL': 'https://www.youtube.com/watch?v=oKVYm8mIUdo'}
# {'날짜 ': '20240424', '랭킹 ': '17', '제목 ': '디스코드', 'Cover_Img': 'https://lh3.googleusercontent.com/SSorroIBWlUYL9GPtSfIiKm94b-IJdUUawDaS1sL4IIuI82jt3b7wyGxcVie1aQnKnH5MG6f2l0G2q7j=w180-h180-l90-rj', '가수 ': 'QWER', '조회수 ': '1,240,376', '영상URL': 'https://www.youtube.com/watch?v=WGm2HmXeeRI'}
# {'날짜 ': '20240424', '랭킹 ': '18', '제목 ': 'Beautiful Things', 'Cover_Img': 'https://lh3.googleusercontent.com/-tOODHuXHt7vMCroq0W-mRNHwg75QKEbp99QtaDKGB-u2MimQ0LnGoazZW9ROwUTIo50Yz6DV-Zkjmmy=w180-h180-l90-rj', '가수 ': 'Benson Boone', '조회수 ': '1,135,505', '영상URL': 'https://www.youtube.com/watch?v=Oa_RSwwpPaA'}
# {'날짜 ': '20240424', '랭킹 ': '19', '제목 ': 'Seven (feat. Latto)', 'Cover_Img': 'https://lh3.googleusercontent.com/6HM8d1d7o2RDgf17Qi-T_XWgOAE8eOxYRWTVmAMxjdKjQ0vzq5rn4zQt1QkGW4fCNEGJifJ50Kboozkj=w180-h180-l90-rj', '가수 ': '정국', '조회수 ': '1,102,506', '영상URL': 'https://www.youtube.com/watch?v=QU9c0053UAU'}
# {'날짜 ': '20240424', '랭킹 ': '20', '제목 ': 'Perfect Night', 'Cover_Img': 'https://lh3.googleusercontent.com/0DgY-1Bl10lB8E2d7Ddo1C4-lPV4wfGrwc01aAhn3kAfYikpd2uopv__p4skqINan_DOw44Ev8PZQE0VoA=w180-h180-l90-rj', '가수 ': '르세라핌', '조회수 ': '1,092,839', '영상URL': 'https://www.youtube.com/watch?v=hLvWy2b857I'}
# {'날짜 ': '20240424', '랭킹 ': '21', '제목 ': 'Rhapsody of Sadness', 'Cover_Img': 'https://i.ytimg.com/vi/TyCYGCCD6iQ/default.jpg', '가수 ': '임재현', '조회수 ': '1,079,362', '영상URL': 'https://www.youtube.com/watch?v=TyCYGCCD6iQ'}
# {'날짜 ': '20240424', '랭킹 ': '22', '제목 ': 'Fortnight (feat. Post Malone(포스트 말론))', 'Cover_Img': 'https://lh3.googleusercontent.com/ynkpsIdsYe1fVEOpJeAO_SzQHJF3rsujhQ4EsmuIdVKavbNm5uDvDTBShK6bPj4I7Sj9Yd6Zvpni2Ktu7g=w180-h180-l90-rj', '가수 ': 'Taylor Swift', '조회수 ': '1,059,378', '영상URL': 'https://www.youtube.com/watch?v=q3zqJs7JUCQ'}
# {'날짜 ': '20240424', '랭킹 ': '23', '제목 ': 'Attention', 'Cover_Img': 'https://lh3.googleusercontent.com/yg7U52lN4NMHddFXE1de6d99puDNeC-1U6q5PnLjXPatrexqW9AOoWC8a5EJBULlXraaEWU8OvKrFYrp1A=w180-h180-l90-rj', '가수 ': 'NewJeans', '조회수 ': '1,059,064', '영상URL': 'https://www.youtube.com/watch?v=js1CtxSY38I'}
# {'날짜 ': '20240424', '랭킹 ': '24', '제목 ': '미안해 미워해 사랑해', 'Cover_Img': 'https://lh3.googleusercontent.com/H-gyBdEhpLyG7Y8HErPTYNUzzJ9niMCRXASuRWGbarQv9KuN0Iv1ZTu4JYHlcx3n9pO-QZOqpQZYhlJzew=w180-h180-l90-rj', '가수 ': '크러쉬', '조회수 ': '1,052,614', '영상URL': 'https://www.youtube.com/watch?v=Z4qVfCi_lUI'}
# {'날짜 ': '20240424', '랭킹 ': '25', '제목 ': 'Shut Down', 'Cover_Img': 'https://lh3.googleusercontent.com/GriPb4nuy0ykhBVO0s1K0aYQBrbosi_ML1F0HYOCrHouOFTpUIm1zijUz7cZVNoVfd_XPWm_DEEhGVk=w180-h180-l90-rj', '가수 ': 'BLACKPINK', '조회수 ': '1,045,532', '영상URL': 'https://www.youtube.com/watch?v=POe9SOEKotk'}
# {'날짜 ': '20240424', '랭킹 ': '26', '제목 ': '후라이의 꿈', 'Cover_Img': 'https://lh3.googleusercontent.com/XSto4YM3BT1tiNpZc4dTLoyzA8iL7RY_2XFkrFWLl-XfdrQ-rgQzb0Sq0WsnFF2vIXAGPQyxbY8Jnrf_=w180-h180-l90-rj', '가수 ': 'AKMU (악뮤)', '조회수 ': '1,009,579', '영상URL': 'https://www.youtube.com/watch?v=3kGAlp_PNUg'}
# {'날짜 ': '20240424', '랭킹 ': '27', '제목 ': 'Welcome to the Show', 'Cover_Img': 'https://lh3.googleusercontent.com/iDTAKK8USdhgUO4ZiVCn2re8WH5nWZUMSBReQowhuJ9EdaZXXMHT6ILnEjzEpU95hX19bYS4IHGljbc=w180-h180-l90-rj', '가수 ': 'DAY6(데이식스)', '조회수 ': '1,003,772', '영상URL': 'https://www.youtube.com/watch?v=RowlrvmyFEk'}
# {'날짜 ': '20240424', '랭킹 ': '28', '제목 ': 'Do or Die', 'Cover_Img': 'https://lh3.googleusercontent.com/uTnwWMEklLK41t4igGqauucTGHrpIOj4JFKZodf7wcIee6EVuoDgG1EGLQQSbJsUa3wPGMnap9TQB5c=w180-h180-l90-rj', '가수 ': '임영웅', '조회수 ': '994,086', '영상URL': 'https://www.youtube.com/watch?v=tJut2wIsC1w'}
# {'날짜 ': '20240424', '랭킹 ': '29', '제목 ': 'If I have you only (My love X Nerd Connection)', 'Cover_Img': 'https://i.ytimg.com/vi/IMWT6937uUs/default.jpg', '가수 ': '너드커넥션', '조회수 ': '949,312', '영상URL': 'https://www.youtube.com/watch?v=IMWT6937uUs'}
# {'날짜 ': '20240424', '랭킹 ': '30', '제목 ': '에피소드', 'Cover_Img': 'https://lh3.googleusercontent.com/GlGpbb_WcFXRlvKysFd3UJ8ZRWtSwATuPG0bPRrHeaEOfALxVUdKozGnN9g382eiSfl98P4Xlbdvswl4-g=w180-h180-l90-rj', '가수 ': '이무진', '조회수 ': '914,308', '영상URL': 'https://www.youtube.com/watch?v=gH1rVdXUlpo'}
# {'날짜 ': '20240424', '랭킹 ': '31', '제목 ': '슬픈 초대장', 'Cover_Img': 'https://lh3.googleusercontent.com/Ffp7l_7-nx3_Bb_nLfjGFPG74-9rIDWZtFjEV7azSS_i0GPmwLseXUqZwJ8vBHbeSzfcpo49zsJfWsagcw=w180-h180-l90-rj', '가수 ': '순순희', '조회수 ': '908,219', '영상URL': 'https://www.youtube.com/watch?v=hkROGL9id6Y'}
# {'날짜 ': '20240424', '랭킹 ': '32', '제목 ': 'You & Me', 'Cover_Img': 'https://lh3.googleusercontent.com/eVDdfPxhtcPPVcYHI-ynRm6yL6549K0wp8SZ-weu3__x09y495LWWmBcTw1XLe8DIC70kaUycGH96mcAkA=w180-h180-l90-rj', '가수 ': '제니', '조회수 ': '878,499', '영상URL': 'https://www.youtube.com/watch?v=eQNHDV7lKgE'}
# {'날짜 ': '20240424', '랭킹 ': '33', '제목 ': 'Bling-Bang-Bang-Born', 'Cover_Img': 'https://lh3.googleusercontent.com/XsPoLNWP9H4eO3xuqDRba8j495lo9wtB_V5ZemS2_fg3jqBMeaYSsk5_PhL1gTkZHAJeE-z1FRSyHbdH=w180-h180-l90-rj', '가수 ': 'Creepy Nuts', '조회수 ': '873,865', '영상URL': 'https://www.youtube.com/watch?v=mLW35YMzELE'}
# {'날짜 ': '20240424', '랭킹 ': '34', '제목 ': 'Super Shy', 'Cover_Img': 'https://lh3.googleusercontent.com/FzLKj6zFEJna0gRNDeZRH4nuQwEyN-YbCaC-bIGLoia6EhirHUachdvdEdR3VdB7pArgFCW8mtpLPL0=w180-h180-l90-rj', '가수 ': 'NewJeans', '조회수 ': '855,030', '영상URL': 'https://www.youtube.com/watch?v=ArmDp-zijuc'}
# {'날짜 ': '20240424', '랭킹 ': '35', '제목 ': 'Earth, Wind & Fire', 'Cover_Img': 'https://lh3.googleusercontent.com/389ctVru8bvIs51SqZlyPBfbfubM46FqGPuir1FdVlDGFyHfmwcI9Z0C0L79VZJJvlMLb35mnkpnfC_s=w180-h180-l90-rj', '가수 ': 'BOYNEXTDOOR', '조회수 ': '838,929', '영상URL': 'https://www.youtube.com/watch?v=u9nP3qXQA4o'}
# {'날짜 ': '20240424', '랭킹 ': '36', '제목 ': '인사', 'Cover_Img': 'https://lh3.googleusercontent.com/15wkXs1Mndc-2cplMMNKNdJHHG6hg4Ui1nYBgcdXcpSZVUvHe1uvQxnLrSnSmTLGS_wjcR7rdxHqjnQ=w180-h180-l90-rj', '가수 ': '범진 BUMJIN', '조회수 ': '833,697', '영상URL': 'https://www.youtube.com/watch?v=H0lQwJPdoBU'}
# {'날짜 ': '20240424', '랭킹 ': '37', '제목 ': 'When you alone', 'Cover_Img': 'https://i.ytimg.com/vi/T5BxR0KNyyQ/default.jpg', '가수 ': 'Woody', '조회수 ': '812,348', '영상URL': 'https://www.youtube.com/watch?v=T5BxR0KNyyQ'}
# {'날짜 ': '20240424', '랭킹 ': '38', '제목 ': 'ETA', 'Cover_Img': 'https://lh3.googleusercontent.com/FzLKj6zFEJna0gRNDeZRH4nuQwEyN-YbCaC-bIGLoia6EhirHUachdvdEdR3VdB7pArgFCW8mtpLPL0=w180-h180-l90-rj', '가수 ': 'NewJeans', '조회수 ': '796,528', '영상URL': 'https://www.youtube.com/watch?v=jOTfBlKSQYY'}
# {'날짜 ': '20240424', '랭킹 ': '39', '제목 ': 'Lucky Girl Syndrome', 'Cover_Img': 'https://lh3.googleusercontent.com/vSYEILsfvGwSZU3PuZPU15DX0FRHcWbDnei-30-ZKQmg5XM9QKlL2BpwF9Obuvls9H3YEAMaqcusetE=w180-h180-l90-rj', '가수 ': 'ILLIT', '조회수 ': '787,617', '영상URL': 'https://www.youtube.com/watch?v=UCmgGZbfjmk'}
# {'날짜 ': '20240424', '랭킹 ': '40', '제목 ': 'Love Lee', 'Cover_Img': 'https://i.ytimg.com/vi/fx227oTnnPc/default.jpg', '가수 ': 'AKMU (악뮤)', '조회수 ': '783,922', '영상URL': 'https://www.youtube.com/watch?v=fx227oTnnPc'}
# {'날짜 ': '20240424', '랭킹 ': '41', '제목 ': '混沌ブギ', 'Cover_Img': 'https://lh3.googleusercontent.com/b_6oZPdbApPvaDBptrF5yUUYsFnM6pfwD2nDZubvYAp3L-s797byEzmSCVqivVd8COTfeXb0m6x0KMqb=w180-h180-l90-rj', '가수 ': 'jon-YAKITORY', '조회수 ': '760,365', '영상URL': 'https://www.youtube.com/watch?v=1Swg-aBO9eY'}
# {'날짜 ': '20240424', '랭킹 ': '42', '제목 ': 'Yes or No (feat. 허윤진 of LE SSERAFIM & Crush)', 'Cover_Img': 'https://i.ytimg.com/vi/59DAuFD9D0U/default.jpg', '가수 ': '그루비룸', '조회수 ': '730,281', '영상URL': 'https://www.youtube.com/watch?v=59DAuFD9D0U'}
# {'날짜 ': '20240424', '랭킹 ': '43', '제목 ': 'DASH', 'Cover_Img': 'https://lh3.googleusercontent.com/8WX8Sku2VQnrH-QasdneYtYdfrR2TN42rlR4ElGsUILCa4FYEW_5ukW8hxC5IoKnMUMG4nO1njMSXHHD=w180-h180-l90-rj', '가수 ': '엔믹스', '조회수 ': '687,821', '영상URL': 'https://www.youtube.com/watch?v=7UecFm_bSTU'}
# {'날짜 ': '20240424', '랭킹 ': '44', '제목 ': 'Spicy', 'Cover_Img': 'https://lh3.googleusercontent.com/uXUcQwZ7-V4CzLtCK2HwbEOy589iKlfsH5FN5MhvCBr8xkAH1LP8rc49rVIKyFohrkTj53pdeOMKdFxPIQ=w180-h180-l90-rj', '가수 ': 'aespa', '조회수 ': '683,888', '영상URL': 'https://www.youtube.com/watch?v=Os_heh8vPfs'}
# {'날짜 ': '20240424', '랭킹 ': '45', '제목 ': 'Lemon', 'Cover_Img': 'https://lh3.googleusercontent.com/Yiqnzq5SfMrNjf9XTAMCPadMclhC8ltAVaePndf64gdwvjaN6eEDFBw2aKRukpqxlb7rdkb27BdUFLIDfA=w180-h180-l90-rj', '가수 ': 'Kenshi Yonezu(켄시 요네즈/米津 玄師)', '조회수 ': '682,115', '영상URL': 'https://www.youtube.com/watch?v=SX_ViT4Ra7k'}
# {'날짜 ': '20240424', '랭킹 ': '46', '제목 ': 'Holssi', 'Cover_Img': 'https://lh3.googleusercontent.com/snFCvIASmExR-2J6lZB85AOsCT2WcM6zh74qoFa5zo0pp1TFeabTplyntaIf1yGJ5iwCRIHKhmxNf3Pv=w180-h180-l90-rj', '가수 ': '아이유(IU)', '조회수 ': '675,118', '영상URL': 'https://www.youtube.com/watch?v=mFbILexYSQg'}
# {'날짜 ': '20240424', '랭킹 ': '47', '제목 ': 'AK47', 'Cover_Img': 'https://i.ytimg.com/vi/C2YKyrhuygI/default.jpg', '가수 ': "Men's Tear (맨스티어)", '조회수 ': '653,243', '영상URL': 'https://www.youtube.com/watch?v=C2YKyrhuygI'}
# {'날짜 ': '20240424', '랭킹 ': '48', '제목 ': 'Pink Venom', 'Cover_Img': 'https://lh3.googleusercontent.com/OeyObLE4rESv5Qu7MruXwBWsCbmXvpJl8652fUKrVzmt6SNYCvZIugmGxHRgBHN_XUSODkH3x6plN_tc=w180-h180-l90-rj', '가수 ': 'BLACKPINK', '조회수 ': '646,848', '영상URL': 'https://www.youtube.com/watch?v=gQlMMD8auMs'}
# {'날짜 ': '20240424', '랭킹 ': '49', '제목 ': '잘자요 아가씨', 'Cover_Img': 'https://i.ytimg.com/vi/7Fsie5WvzFM/default.jpg', '가수 ': 'ASMRZ(다나카&닛몰캐쉬)', '조회수 ': '644,034', '영상URL': 'https://www.youtube.com/watch?v=7Fsie5WvzFM'}
# {'날짜 ': '20240424', '랭킹 ': '50', '제목 ': '晩餐歌', 'Cover_Img': 'https://lh3.googleusercontent.com/8tpu5dF-yDIzUcc0dnurD5dk6CzP27LlmYLrRr9hBpQeialEq7lyS-EtqrKTLw3F6hHOW2hxIzUsdVHy=w180-h180-l90-rj', '가수 ': 'tuki.', '조회수 ': '629,932', '영상URL': 'https://www.youtube.com/watch?v=oZpYEEcvu5I'}
# {'날짜 ': '20240424', '랭킹 ': '51', '제목 ': 'Pretty Savage', 'Cover_Img': 'https://lh3.googleusercontent.com/ZKINUFCtfMUKB4CH4wJcQyHi6-bmuHz2exRBV6SORUd96KsC1jo2nrDImg2zlLnvHgJPGBxreYVjunGycg=w180-h180-l90-rj', '가수 ': 'BLACKPINK', '조회수 ': '621,209', '영상URL': 'https://www.youtube.com/watch?v=F8c8f2nK82w'}
# {'날짜 ': '20240424', '랭킹 ': '52', '제목 ': 'Siren', 'Cover_Img': 'https://i.ytimg.com/vi/m6M6awqPPns/default.jpg', '가수 ': 'RIIZE', '조회수 ': '581,546', '영상URL': 'https://www.youtube.com/watch?v=m6M6awqPPns'}
# {'날짜 ': '20240424', '랭킹 ': '53', '제목 ': '하늘 여행', 'Cover_Img': 'https://lh3.googleusercontent.com/sbt39JtT4cZ84PUgA84_hkC23o10y4Es_TJyvsiQNf0w2sWGwxqhreI0XJw4M5QylMRhqxgejymnSKc=w180-h180-l90-rj', '가수 ': '이찬원', '조회수 ': '574,656', '영상URL': 'https://www.youtube.com/watch?v=AhmRaCQayv8'}
# {'날짜 ': '20240424', '랭킹 ': '54', '제목 ': 'When Spring Comes', 'Cover_Img': 'https://i.ytimg.com/vi/Jmr_EEDkV-U/default.jpg', '가수 ': '로이킴', '조회수 ': '570,048', '영상URL': 'https://www.youtube.com/watch?v=Jmr_EEDkV-U'}
# {'날짜 ': '20240424', '랭킹 ': '55', '제목 ': '개화', 'Cover_Img': 'https://lh3.googleusercontent.com/ZrPTG4bWV7ghQcQlADT4VMHridOsQDcEj65OIJ0u41EDaVdQxabZmepcySXgvJtUYIHy1hKMw51EiiblrA=w180-h180-l90-rj', '가수 ': '루시', '조회수 ': '559,388', '영상URL': 'https://www.youtube.com/watch?v=2-P-NIiLiQc'}
# {'날짜 ': '20240424', '랭킹 ': '56', '제목 ': 'LADY', 'Cover_Img': 'https://lh3.googleusercontent.com/7e0qJAww69B2DFDDUgFqp59lWMXzuHGS-GG_BFR1sD8rcO80G71aP86hV9NGCqsjx4dMEzO1yxZojAA=w180-h180-l90-rj', '가수 ': 'Kenshi Yonezu(켄시 요네즈/米津 玄師)', '조회수 ': '559,108', '영상URL': 'https://www.youtube.com/watch?v=Qg5Gov_dTSY'}
# {'날짜 ': '20240424', '랭킹 ': '57', '제목 ': '우연히 봄', 'Cover_Img': 'https://lh3.googleusercontent.com/kIyyTFfwscQuCYwkSIieGdOD41IisjLojdktAjlnii-aQJ8VxiBg9LfZgFt4Prax37K1-nyZ78CJwXM=w180-h180-l90-rj', '가수 ': '로꼬 & 유주 (여자친구)', '조회수 ': '556,140', '영상URL': 'https://www.youtube.com/watch?v=GjyMuHmzxVE'}
# {'날짜 ': '20240424', '랭킹 ': '58', '제목 ': 'Propose', 'Cover_Img': 'https://i.ytimg.com/vi/e7JladYoq9U/default.jpg', '가수 ': '이무진', '조회수 ': '544,126', '영상URL': 'https://www.youtube.com/watch?v=e7JladYoq9U'}
# {'날짜 ': '20240424', '랭킹 ': '59', '제목 ': "I'll See You There Tomorrow", 'Cover_Img': 'https://lh3.googleusercontent.com/ufORmdV2sxRBzC1hsCLNujgR7vL8WuFVUWkGZI7gL5yCZNXbr97qoSMgT5fUz1i5aMPhAd0SZZOrTeI=w180-h180-l90-rj', '가수 ': '투모로우바이투게더', '조회수 ': '543,159', '영상URL': 'https://www.youtube.com/watch?v=2_ZQpWVMn9c'}
# {'날짜 ': '20240424', '랭킹 ': '60', '제목 ': 'さよーならまたいつか！- Sayonara', 'Cover_Img': 'https://lh3.googleusercontent.com/HvqODYiGxjyjxOtAtoxaJnyCTQ_DPZq4i-Mociz9nSXelF_ONQgA5Kko9zOAZEbDYrFzeE0LNlzEB_qbXg=w180-h180-l90-rj', '가수 ': 'Kenshi Yonezu(켄시 요네즈/米津 玄師)', '조회수 ': '534,524', '영상URL': 'https://www.youtube.com/watch?v=-wb2PAx6aEs'}
# {'날짜 ': '20240424', '랭킹 ': '61', '제목 ': 'Love 119', 'Cover_Img': 'https://lh3.googleusercontent.com/0rVhke8mYtdDO3OEtopvHmzYlMqCHSIh-kWt5xHxZaMIc5ZcmQkxN5UI_4UtMty89DyzBfTZrHoJdgI=w180-h180-l90-rj', '가수 ': 'RIIZE', '조회수 ': '531,513', '영상URL': 'https://www.youtube.com/watch?v=0TAAUWHo4Ec'}
# {'날짜 ': '20240424', '랭킹 ': '62', '제목 ': '칵테일 사랑', 'Cover_Img': 'https://lh3.googleusercontent.com/3AHx5aJIEbxggMvD8ggX6ixGnY_VjsJL9kjVpfQSvunacP-rBt6DJ3PRaKKGvFjiLRcyrbzH56q1ieve=w180-h180-l90-rj', '가수 ': '경서', '조회수 ': '530,994', '영상URL': 'https://www.youtube.com/watch?v=WxH1Vss1pLo'}
# {'날짜 ': '20240424', '랭킹 ': '63', '제목 ': 'Shopper', 'Cover_Img': 'https://lh3.googleusercontent.com/snFCvIASmExR-2J6lZB85AOsCT2WcM6zh74qoFa5zo0pp1TFeabTplyntaIf1yGJ5iwCRIHKhmxNf3Pv=w180-h180-l90-rj', '가수 ': '아이유(IU)', '조회수 ': '515,325', '영상URL': 'https://www.youtube.com/watch?v=2dVlwcviCwQ'}
# {'날짜 ': '20240424', '랭킹 ': '64', '제목 ': 'Love me or Leave me', 'Cover_Img': 'https://i.ytimg.com/vi/0JxcsbPcEpU/default.jpg', '가수 ': 'DAY6(데이식스)', '조회수 ': '498,829', '영상URL': 'https://www.youtube.com/watch?v=0JxcsbPcEpU'}
# {'날짜 ': '20240424', '랭킹 ': '65', '제목 ': 'Kill This Love', 'Cover_Img': 'https://lh3.googleusercontent.com/a4HLoL-xV0NngaNLLlJ0NjWeHeiAmHv2CF-HmE8AWPuoTc60cwzfCFaE5e9lNM2aYCFd6BmXUMfJj8o=w180-h180-l90-rj', '가수 ': 'BLACKPINK', '조회수 ': '497,333', '영상URL': 'https://www.youtube.com/watch?v=2S24-y0Ij3Y'}
# {'날짜 ': '20240424', '랭킹 ': '66', '제목 ': '멈춰줘', 'Cover_Img': 'https://lh3.googleusercontent.com/q4reT7vLSVNTL2kKUslXqv9FmVHREl7uzeiONIuB7HZN8XKcsIIj5xRZHWaC7P56WKt_9fJc2JIkLCA=w180-h180-l90-rj', '가수 ': '헤이즈(Heize)', '조회수 ': '495,041', '영상URL': 'https://www.youtube.com/watch?v=jRRCWFLAO6k'}
# {'날짜 ': '20240424', '랭킹 ': '67', '제목 ': 'By Your Side', 'Cover_Img': 'https://i.ytimg.com/vi/gqX5BTVAeJ4/default.jpg', '가수 ': '크러쉬', '조회수 ': '494,100', '영상URL': 'https://www.youtube.com/watch?v=gqX5BTVAeJ4'}
# {'날짜 ': '20240424', '랭킹 ': '68', '제목 ': 'Super Lady', 'Cover_Img': 'https://lh3.googleusercontent.com/-d5I1nv7x56NNuD3nbMZDRG874qNwua2usmDnVM35VGwHbLlLw8ozDMUrClz7f0lnSbG40L_dAF75EU8=w180-h180-l90-rj', '가수 ': '(여자)아이들', '조회수 ': '491,310', '영상URL': 'https://www.youtube.com/watch?v=6f3RzjXPQwA'}
# {'날짜 ': '20240424', '랭킹 ': '69', '제목 ': '좋아해요', 'Cover_Img': 'https://i.ytimg.com/vi/mvVzdTX0yVs/default.jpg', '가수 ': '폴킴(Paul Kim)', '조회수 ': '483,586', '영상URL': 'https://www.youtube.com/watch?v=mvVzdTX0yVs'}
# {'날짜 ': '20240424', '랭킹 ': '70', '제목 ': '고장난걸까', 'Cover_Img': 'https://lh3.googleusercontent.com/6_Wrg4zoOe0WPe_8cFgVzZtm9eTVLrhN1_1zhWDVDCCEU-sweemy6titSkpQy3bc0KCiX5YBOPpzi1aR=w180-h180-l90-rj', '가수 ': '10CM', '조회수 ': '476,475', '영상URL': 'https://www.youtube.com/watch?v=_j0BOGdmh38'}
# {'날짜 ': '20240424', '랭킹 ': '71', '제목 ': 'Typa Girl', 'Cover_Img': 'https://i.ytimg.com/vi/oMsizmQ9l5c/default.jpg', '가수 ': 'BLACKPINK', '조회수 ': '471,943', '영상URL': 'https://www.youtube.com/watch?v=oMsizmQ9l5c'}
# {'날짜 ': '20240424', '랭킹 ': '72', '제목 ': '반딧불', 'Cover_Img': 'https://lh3.googleusercontent.com/OP81GLXV13-d6w4riAe4e5Yb-iisE0tFOLQV2pLUhoqBVNe33MK-cYpuWHredpu-azeVBOfQH2xY4Aebxg=w180-h180-l90-rj', '가수 ': '도영 (DOYOUNG)', '조회수 ': '471,849', '영상URL': 'https://www.youtube.com/watch?v=UZjGcAjd8Ok'}
# {'날짜 ': '20240424', '랭킹 ': '73', '제목 ': 'HAPPY (Live)', 'Cover_Img': 'https://i.ytimg.com/vi/sWXGbkM0tBI/default.jpg', '가수 ': 'DAY6(데이식스)', '조회수 ': '449,884', '영상URL': 'https://www.youtube.com/watch?v=sWXGbkM0tBI'}
# {'날짜 ': '20240424', '랭킹 ': '74', '제목 ': "The knight who can't die and the silk cradle", 'Cover_Img': 'https://lh3.googleusercontent.com/e6y1VJt1RFgZtYcItQE0_PJAgjqZ8fFKdSFmrJO_9WFY1kRC3y5oIu_0rI-wpyM6mLW_2vyncg0PV-k=w180-h180-l90-rj', '가수 ': '루시', '조회수 ': '449,410', '영상URL': 'https://www.youtube.com/watch?v=Q9Nvvz6pd9g'}
# {'날짜 ': '20240424', '랭킹 ': '75', '제목 ': 'BAD', 'Cover_Img': 'https://lh3.googleusercontent.com/-JqvsdsCIkRxHZwd14bU7rZ9qZbtlc6kEqa-CIuKlzFOjVGqVdqHpAFzyQiy5aLVoW55bBhki6ZtraYp=w180-h180-l90-rj', '가수 ': '크리스토퍼', '조회수 ': '435,660', '영상URL': 'https://www.youtube.com/watch?v=ACiyYOz0wsQ'}
# {'날짜 ': '20240424', '랭킹 ': '76', '제목 ': 'Deja Vu', 'Cover_Img': 'https://lh3.googleusercontent.com/ufORmdV2sxRBzC1hsCLNujgR7vL8WuFVUWkGZI7gL5yCZNXbr97qoSMgT5fUz1i5aMPhAd0SZZOrTeI=w180-h180-l90-rj', '가수 ': '투모로우바이투게더', '조회수 ': '432,669', '영상URL': 'https://www.youtube.com/watch?v=DiHUEWBRQEI'}
# {'날짜 ': '20240424', '랭킹 ': '77', '제목 ': 'Architect', 'Cover_Img': 'https://i.ytimg.com/vi/QkNzZUVToyM/default.jpg', '가수 ': 'Livingston', '조회수 ': '431,472', '영상URL': 'https://www.youtube.com/watch?v=QkNzZUVToyM'}
# {'날짜 ': '20240424', '랭킹 ': '78', '제목 ': 'Last Chance', 'Cover_Img': 'https://lh3.googleusercontent.com/DFWE9aDgzreMO2jdf5yn3v5s-0gRDPT30qPKaJGrl1n14NnmwpJ3yC2wyzT2WFRF2CBak6Jp9PV9xTBrjw=w180-h180-l90-rj', '가수 ': '소수빈', '조회수 ': '429,274', '영상URL': 'https://www.youtube.com/watch?v=TcHIPSX8Kww'}
# {'날짜 ': '20240424', '랭킹 ': '79', '제목 ': 'Bye My Monster', 'Cover_Img': 'https://lh3.googleusercontent.com/qO96BuUoqcn2SOxmK-EThluCWYhLlxfsnhxgWX7ghknfR6gaLgdoIjfSXK-OzGx3oqOPIi2dPsxr6Fkf=w180-h180-l90-rj', '가수 ': '온앤오프', '조회수 ': '422,764', '영상URL': 'https://www.youtube.com/watch?v=pOR8CUeTJpc'}
# {'날짜 ': '20240424', '랭킹 ': '80', '제목 ': "Fallin'", 'Cover_Img': 'https://lh3.googleusercontent.com/ved5_EBZqjsAKjW_h0WMA7xE4SM33jsnel3q_iE15z6mLeYZXEz-0b_QiqbdjUtsYeGZ5u-c2fInr0U=w180-h180-l90-rj', '가수 ': '홍이삭', '조회수 ': '414,127', '영상URL': 'https://www.youtube.com/watch?v=jbjZ9kcmvD0'}
# {'날짜 ': '20240424', '랭킹 ': '81', '제목 ': '너의 편이 돼 줄게', 'Cover_Img': 'https://i.ytimg.com/vi/HFs-TxyawgA/default.jpg', '가수 ': '다비치', '조회수 ': '410,164', '영상URL': 'https://www.youtube.com/watch?v=HFs-TxyawgA'}
# {'날짜 ': '20240424', '랭킹 ': '82', '제목 ': 'ラビットホール', 'Cover_Img': 'https://lh3.googleusercontent.com/Z9TGDzfodWkXjXx9GRZblyMRAGuZELqK017cd78KZ8Y94kkhtktT-99O0ZTjZnYYoNvVQZwmVkMns0cY=w180-h180-l90-rj', '가수 ': 'DECO*27', '조회수 ': '407,844', '영상URL': 'https://www.youtube.com/watch?v=eSW2LVbPThw'}
# {'날짜 ': '20240424', '랭킹 ': '83', '제목 ': '다시 사랑한다면 (니글니글 버터플라이)', 'Cover_Img': 'https://i.ytimg.com/vi/NU6XxRcx5LA/default.jpg', '가수 ': '김필', '조회수 ': '402,655', '영상URL': 'https://www.youtube.com/watch?v=NU6XxRcx5LA'}
# {'날짜 ': '20240424', '랭킹 ': '84', '제목 ': 'I stan U', 'Cover_Img': 'https://i.ytimg.com/vi/_ZfT3M6ZKEM/default.jpg', '가수 ': '아이유(IU)', '조회수 ': '398,412', '영상URL': 'https://www.youtube.com/watch?v=_ZfT3M6ZKEM'}
# {'날짜 ': '20240424', '랭킹 ': '85', '제목 ': 'サムライハート(Some Like It Hot!!)', 'Cover_Img': 'https://lh3.googleusercontent.com/Tav3o7W_Ef7dz7zbd7ZRqLok9CO9ZxqmenYX_VyHeTQ5IL5TqKHQ-DuRnLPUiZ1ySCksiTbSciMm6SQ=w180-h180-l90-rj', '가수 ': '스파이에어', '조회수 ': '396,481', '영상URL': 'https://www.youtube.com/watch?v=KpM6xNAgRoI'}
# {'날짜 ': '20240424', '랭킹 ': '86', '제목 ': '자꾸만 웃게 돼', 'Cover_Img': 'https://lh3.googleusercontent.com/r9o5gyrnuKtEYN19iaff-iKOCUJYByyo8y9nyon4EvqkIgj-_Sd0MedAvoER9FaV5Pvu3a4lnMGJg6tu=w180-h180-l90-rj', '가수 ': '부석순(SEVENTEEN)', '조회수 ': '388,715', '영상URL': 'https://www.youtube.com/watch?v=ucpb4BYNJ6s'}
# {'날짜 ': '20240424', '랭킹 ': '87', '제목 ': 'Wife', 'Cover_Img': 'https://lh3.googleusercontent.com/-d5I1nv7x56NNuD3nbMZDRG874qNwua2usmDnVM35VGwHbLlLw8ozDMUrClz7f0lnSbG40L_dAF75EU8=w180-h180-l90-rj', '가수 ': '(여자)아이들', '조회수 ': '381,072', '영상URL': 'https://www.youtube.com/watch?v=baaNwRAhHBo'}
# {'날짜 ': '20240424', '랭킹 ': '88', '제목 ': "I Ain't Worried", 'Cover_Img': 'https://lh3.googleusercontent.com/3wlF7gwK6D-aXMqRc0_NtBi9_-3p-SJY3L9hjcFzp4JSEMUTN8SBoELpNDy4eHbDhyd5YNlH3l6289Is=w180-h180-l90-rj', '가수 ': 'OneRepublic(원리퍼블릭)', '조회수 ': '379,933', '영상URL': 'https://www.youtube.com/watch?v=mNEUkkoUoIA'}
# {'날짜 ': '20240424', '랭킹 ': '89', '제목 ': "마지막처럼 (As If It's Your Last)", 'Cover_Img': 'https://lh3.googleusercontent.com/FUz45S6Nmeec1qEpMfcCN_9PvjdLIKffPsi5n7A6KB3rz0eXIRtxd14On1Bgn65T30c_u7LnzkqINAIW=w180-h180-l90-rj', '가수 ': 'BLACKPINK', '조회수 ': '376,982', '영상URL': 'https://www.youtube.com/watch?v=Amq-qlqbjYA'}
# {'날짜 ': '20240424', '랭킹 ': '90', '제목 ': 'LOVE DAY (2021) [From Naver Webtoon "Romance 101"]', 'Cover_Img': 'https://i.ytimg.com/vi/5_Esp-dXcOA/default.jpg', '가수 ': '양요섭 & 정은지', '조회수 ': '374,945', '영상URL': 'https://www.youtube.com/watch?v=5_Esp-dXcOA'}
# {'날짜 ': '20240424', '랭킹 ': '91', '제목 ': '영원', 'Cover_Img': 'https://i.ytimg.com/vi/YApzsfazibE/default.jpg', '가수 ': 'DK (디셈버)', '조회수 ': '374,443', '영상URL': 'https://www.youtube.com/watch?v=YApzsfazibE'}
# {'날짜 ': '20240424', '랭킹 ': '92', '제목 ': 'DINOSAUR', 'Cover_Img': 'https://lh3.googleusercontent.com/lmZVjzAoE74M1QbGCXiRqDvlVXh6jvq1-9UTdpRokjgitGhQ2at5TMP4offwmwsAPpBnJJrJwOOT4S4YeA=w180-h180-l90-rj', '가수 ': 'AKMU (악뮤)', '조회수 ': '369,163', '영상URL': 'https://www.youtube.com/watch?v=8Oz7DG76ibY'}
# {'날짜 ': '20240424', '랭킹 ': '93', '제목 ': '뚜두뚜두 (DDU-DU DDU-DU)', 'Cover_Img': 'https://lh3.googleusercontent.com/99KTB7qNOoQ4vmGh9HrHb01iwjn2RgigV30O0j319AG3lGC-1rTLWJy8v9G49Od37gu13UBd8DnzEfq_=w180-h180-l90-rj', '가수 ': 'BLACKPINK', '조회수 ': '367,570', '영상URL': 'https://www.youtube.com/watch?v=IHNzOHi8sJs'}
# {'날짜 ': '20240424', '랭킹 ': '94', '제목 ': 'I’m Ready', 'Cover_Img': 'https://lh3.googleusercontent.com/7hPr34VOZEHRVqOMuFg4IJ_-QKVDPmaXejm0Yw70f2bPbngYB3Umdxa-6UrjZmVADP-fne_57B9gp6rj=w180-h180-l90-rj', '가수 ': '청하', '조회수 ': '360,632', '영상URL': 'https://www.youtube.com/watch?v=jf0_fwHYAbE'}
# {'날짜 ': '20240424', '랭킹 ': '95', '제목 ': 'ビビデバ', 'Cover_Img': 'https://lh3.googleusercontent.com/PF_2f7RHccFiCWvhd8_21UhNLCtL-d23_Om5es-CAaWHTej2MS8CBGsDeDee9RMqkdyVx4sSmrK8vQO3wQ=w180-h180-l90-rj', '가수 ': 'Suisei Hoshimachi', '조회수 ': '357,739', '영상URL': 'https://www.youtube.com/watch?v=8ZP5eqm4JqM'}
# {'날짜 ': '20240424', '랭킹 ': '96', '제목 ': '우산 (Umbrella) (feat. 윤하)', 'Cover_Img': 'https://lh3.googleusercontent.com/14mT-t-KXnjnLvMf-HDUVf7blyzeKCgTiE7AwVPeB9sXW7E4N01Hoxw3FBpMqBAbO_dd9dd1Kmwz_eQ6=w180-h180-l90-rj', '가수 ': '에픽하이(EPIK HIGH)', '조회수 ': '357,728', '영상URL': 'https://www.youtube.com/watch?v=NIPtyAKxlRs'}
# {'날짜 ': '20240424', '랭킹 ': '97', '제목 ': 'flutter', 'Cover_Img': 'https://lh3.googleusercontent.com/23vxujoDsU7ZdukYp__v3Jnf2J_vnJM2amniSzVCClMRPvIx6_VsrJkX0yilYizXR9JdLrG0M2kNyBv7hA=w180-h180-l90-rj', '가수 ': '경서', '조회수 ': '357,486', '영상URL': 'https://www.youtube.com/watch?v=MQvGxUB-AlY'}
# {'날짜 ': '20240424', '랭킹 ': '98', '제목 ': '너에게 난, 나에게 넌', 'Cover_Img': 'https://i.ytimg.com/vi/SZkkZLSCv44/default.jpg', '가수 ': '자전거 탄 풍경', '조회수 ': '349,302', '영상URL': 'https://www.youtube.com/watch?v=SZkkZLSCv44'}
# {'날짜 ': '20240424', '랭킹 ': '99', '제목 ': 'Cruel Summer', 'Cover_Img': 'https://lh3.googleusercontent.com/OhxDTHQOQzSrcdgH9hzqzp1v22GYDE-QKnkryvCeq4ddx-3K3_c8oDXN0E6NvHlMn1q4XV59aHr0oL4f=w180-h180-l90-rj', '가수 ': 'Taylor Swift', '조회수 ': '347,698', '영상URL': 'https://www.youtube.com/watch?v=ic8j13piAhQ'}
# {'날짜 ': '20240424', '랭킹 ': '100', '제목 ': '꿈', 'Cover_Img': 'https://lh3.googleusercontent.com/LbC4cFatDGDjBBR4W39ERjdw5eEOR3laSD-2rK4tPeaMImeVjZEkygiX8qdP6opp3Z0CK98GSVbrYgk=w180-h180-l90-rj', '가수 ': '태연', '조회수 ': '341,608', '영상URL': 'https://www.youtube.com/watch?v=dMaU3Mj7EVY'}
# https://charts.youtube.com/charts/TopSongs/kr/weekly/20240502
# Count : 20240502 / End_Count : 20240429
# Excel 파일이 저장되었습니다: C:\P_Project\1.Project\5-Project_data\6.Youtube_Crawling_Final4.29.xlsx
