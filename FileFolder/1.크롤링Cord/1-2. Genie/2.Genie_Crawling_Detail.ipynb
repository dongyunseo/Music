# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime, timedelta
from openpyxl import Workbook
import re

sns.set_style('darkgrid')
sns.set_palette('Set3')
warnings.filterwarnings('ignore')
plt.rcParams["font.family"] = "NanumBarunGothic"

# %%
# pip install openpyxl
path = "C:/P_Project/1.Project/5-Project_data"
# main = pd.read_excel(path + '/국립중앙도서관 대출 데이터/NL_CO_LOAN_PUB_202311-7.xlsx')
Top_Lib = pd.read_excel(path + '/2.Genie_No_Detail4.29.2.xlsx')

# 상세정보를 크롤링하기위해 앨범코드만 추출
Album_codes_column = Top_Lib['SongId']

# 중복된 데이터 제거
Unique_Album_codes = list(set(Album_codes_column))
num_records = len(Unique_Album_codes)
# 결과 출력
print(f"데이터 수: {num_records}")
# Out:
# 데이터 수: 100

# %%
headers = {
   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# 엑셀 파일 생성
wb = Workbook()
ws = wb.active

# 헤더 추가
ws.append(['SongId', '장르'])

Count = 0

for detail in Unique_Album_codes:
   response_Detail = requests.get("https://www.genie.co.kr/detail/songInfo?xgnm={0}".format(detail), headers=headers)
   URL_Detail = "https://www.genie.co.kr/detail/songInfo?xgnm={0}".format(detail)
         
   html_Detail = response_Detail.content.decode('utf-8','replace')
   soup_Detail = BeautifulSoup(html_Detail, 'html.parser',from_encoding='cp949')

   Count += 1
   print(f"Count : {Count}/780")
   print(URL_Detail)
   
   my_st_Detail = soup_Detail.select(
      '#body-content > div.song-main-infos > div.info-zone > ul'
   )
   for stock_name in my_st_Detail:
      # 장르
      Genre = stock_name.select_one('li:nth-child(4) > span.value').text.strip()

      # 데이터 추가
      for Genre_Text in zip(Genre):
         ws.append([detail, Genre])

      
      print(detail, Genre)
      # Count += 1
      # print(f"Count : {Count}, 총Count : {num_records}")
      
      
# 엑셀 파일 저장
file_path = r"C:\P_Project\1.Project\5-Project_data\2.Genie_detail_Data4.29.xlsx"
wb.save(file_path)
print("Excel 파일이 저장되었습니다:", file_path)
# Out:
# Count : 1/780
# https://www.genie.co.kr/detail/songInfo?xgnm=100080644
# 100080644 가요 / 인디
# Count : 2/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105563654
# 105563654 가요 / 발라드
# Count : 3/780
# https://www.genie.co.kr/detail/songInfo?xgnm=102664199
# 102664199 가요 / 댄스
# Count : 4/780
# https://www.genie.co.kr/detail/songInfo?xgnm=89220627
# 89220627 가요 / 락
# Count : 5/780
# https://www.genie.co.kr/detail/songInfo?xgnm=85902364
# 85902364 POP / 팝
# Count : 6/780
# https://www.genie.co.kr/detail/songInfo?xgnm=94535712
# 94535712 OST / 드라마
# Count : 7/780
# https://www.genie.co.kr/detail/songInfo?xgnm=96482850
# 96482850 가요 / 락
# Count : 8/780
# https://www.genie.co.kr/detail/songInfo?xgnm=97976355
# 97976355 가요 / 댄스
# Count : 9/780
# https://www.genie.co.kr/detail/songInfo?xgnm=106030116
# 106030116 OST / 드라마
# Count : 10/780
# https://www.genie.co.kr/detail/songInfo?xgnm=106290214
# 106290214 가요 / 랩/힙합
# Count : 11/780
# https://www.genie.co.kr/detail/songInfo?xgnm=95376934
# 95376934 가요 / 발라드
# Count : 12/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105544232
# 106028758 가요 / 락
# Count : 43/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105938136
# 105938136 가요 / 락
# Count : 44/780
# https://www.genie.co.kr/detail/songInfo?xgnm=102724316
# 102724316 가요 / 댄스
# Count : 45/780
# https://www.genie.co.kr/detail/songInfo?xgnm=103151854
# 103151854 가요 / 댄스
# Count : 46/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105293063
# 105293063 가요 / 발라드
# Count : 47/780
# https://www.genie.co.kr/detail/songInfo?xgnm=96613134
# 96613134 가요 / 인디
# Count : 48/780
# https://www.genie.co.kr/detail/songInfo?xgnm=96276241
# 96276241 가요 / 락
# Count : 49/780
# https://www.genie.co.kr/detail/songInfo?xgnm=101479700
# 101479700 가요 / 댄스
# Count : 50/780
# https://www.genie.co.kr/detail/songInfo?xgnm=88686378
# 88686378 가요 / 인디
# Count : 51/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105464107
# 105464107 가요 / R&B/소울
# Count : 52/780
# https://www.genie.co.kr/detail/songInfo?xgnm=93717294
# 93717294 POP / 팝
# Count : 53/780
# https://www.genie.co.kr/detail/songInfo?xgnm=96480048
# 96480048 가요 / 댄스
# Count : 54/780
# https://www.genie.co.kr/detail/songInfo?xgnm=104169271
# 104169271 가요 / 댄스
# Count : 55/780
# https://www.genie.co.kr/detail/songInfo?xgnm=82280761
# 82280761 OST / 드라마
# Count : 56/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105666874
# 105666874 가요 / 발라드
# Count : 57/780
# https://www.genie.co.kr/detail/songInfo?xgnm=99635005
# 99635005 가요 / 댄스
# Count : 58/780
# https://www.genie.co.kr/detail/songInfo?xgnm=101529417
# 101529417 가요 / 발라드
# Count : 59/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105544011
# 105544011 가요 / 랩/힙합
# Count : 60/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105544013
# 105544013 가요 / 락
# Count : 61/780
# https://www.genie.co.kr/detail/songInfo?xgnm=95443285
# 95443285 가요 / 인디
# Count : 62/780
# https://www.genie.co.kr/detail/songInfo?xgnm=99570005
# 99570005 가요 / 댄스
# Count : 63/780
# https://www.genie.co.kr/detail/songInfo?xgnm=103903575
# 103903575 가요 / 댄스
# Count : 64/780
# https://www.genie.co.kr/detail/songInfo?xgnm=101593941
# 101593941 가요 / 댄스
# Count : 65/780
# https://www.genie.co.kr/detail/songInfo?xgnm=87928158
# 87928158 POP / 팝
# Count : 66/780
# https://www.genie.co.kr/detail/songInfo?xgnm=96042335
# 96042335 OST / 드라마
# Count : 67/780
# https://www.genie.co.kr/detail/songInfo?xgnm=99792734
# 99792734 가요 / 댄스
# Count : 68/780
# https://www.genie.co.kr/detail/songInfo?xgnm=101713249
# 101713249 가요 / 발라드
# Count : 69/780
# https://www.genie.co.kr/detail/songInfo?xgnm=102563175
# 102563175 가요 / 댄스
# Count : 70/780
# https://www.genie.co.kr/detail/songInfo?xgnm=87840106
# 87840106 OST / 드라마
# Count : 71/780
# https://www.genie.co.kr/detail/songInfo?xgnm=16151403
# 16151403 OST / 한국영화
# Count : 72/780
# https://www.genie.co.kr/detail/songInfo?xgnm=103151984
# 103151984 가요 / 댄스
# Count : 73/780
# https://www.genie.co.kr/detail/songInfo?xgnm=103151985
# 103151985 가요 / 블루스/포크
# Count : 74/780
# https://www.genie.co.kr/detail/songInfo?xgnm=104821618
# 104821618 가요 / 락
# Count : 75/780
# https://www.genie.co.kr/detail/songInfo?xgnm=93336453
# 93336453 가요 / 발라드
# Count : 76/780
# https://www.genie.co.kr/detail/songInfo?xgnm=106150790
# 106150790 가요 / R&B/소울
# Count : 77/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105858458
# 105858458 가요 / 발라드
# Count : 78/780
# https://www.genie.co.kr/detail/songInfo?xgnm=101407645
# 101407645 가요 / 발라드
# Count : 79/780
# https://www.genie.co.kr/detail/songInfo?xgnm=97582506
# 97582506 가요 / 댄스
# Count : 80/780
# https://www.genie.co.kr/detail/songInfo?xgnm=97582507
# 97582507 가요 / 댄스
# Count : 81/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105260463
# 105260463 가요 / 댄스
# Count : 82/780
# https://www.genie.co.kr/detail/songInfo?xgnm=101686193
# 101686193 가요 / 댄스
# Count : 83/780
# https://www.genie.co.kr/detail/songInfo?xgnm=93300145
# 93300145 가요 / 락
# Count : 84/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105260468
# 105260468 가요 / 댄스
# Count : 85/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105757621
# 105757621 가요 / 락
# Count : 86/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105260470
# 105260470 가요 / 댄스
# Count : 87/780
# https://www.genie.co.kr/detail/songInfo?xgnm=103952831
# 103952831 가요 / 락
# Count : 88/780
# https://www.genie.co.kr/detail/songInfo?xgnm=104277953
# 104277953 가요 / 댄스
# Count : 89/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105812421
# 105812421 가요 / 발라드
# Count : 90/780
# https://www.genie.co.kr/detail/songInfo?xgnm=104873418
# 104873418 OST / 드라마
# Count : 91/780
# https://www.genie.co.kr/detail/songInfo?xgnm=98304971
# 98304971 POP / 팝
# Count : 92/780
# https://www.genie.co.kr/detail/songInfo?xgnm=89320910
# 89320910 OST / 드라마
# Count : 93/780
# https://www.genie.co.kr/detail/songInfo?xgnm=96550868
# 96550868 POP / 일렉트로니카
# Count : 94/780
# https://www.genie.co.kr/detail/songInfo?xgnm=86931930
# 86931930 가요 / 락
# Count : 95/780
# https://www.genie.co.kr/detail/songInfo?xgnm=104919515
# 104919515 가요 / 발라드
# Count : 96/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105872348
# 105872348 OST / 드라마
# Count : 97/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105739242
# 105739242 OST / 드라마
# Count : 98/780
# https://www.genie.co.kr/detail/songInfo?xgnm=105991671
# 105991671 가요 / 댄스
# Count : 99/780
# https://www.genie.co.kr/detail/songInfo?xgnm=103024121
# 103024121 가요 / 발라드
# Count : 100/780
# https://www.genie.co.kr/detail/songInfo?xgnm=89382909
# 89382909 가요 / 발라드
# Excel 파일이 저장되었습니다: C:\P_Project\1.Project\5-Project_data\2.Genie_detail_Data4.29.xlsx
